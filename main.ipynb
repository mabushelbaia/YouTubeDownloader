# %% [markdown]
# # Videos Downloader

# %%
import os
import pandas as pd
import yt_dlp
from googleapiclient.discovery import build
from dotenv import load_dotenv

# Load the environment variables
load_dotenv()

# Set up the API client
api_key = os.getenv('API_KEY')
youtube = build('youtube', 'v3', developerKey=api_key)
channel_id = 'UCMwXnEIdNOe_nEcfqzjOO7A'

# %% [markdown]
# ### Get Channel Videos

# %%
def get_uploads_playlist_id(channel_id):
    """Retrieve the uploads playlist ID for a given channel ID."""
    try:
        channel_response = youtube.channels().list(
            part='contentDetails',
            id=channel_id
        ).execute()
        uploads_playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        return uploads_playlist_id
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

uploads_playlist = get_uploads_playlist_id(channel_id)
print(f"Uploads playlist ID: {uploads_playlist}")
# Out:
# Uploads playlist ID: UUMwXnEIdNOe_nEcfqzjOO7A

# %%
def get_videos_from_playlist(playlist_id):
    """Retrieve all videos from a given playlist ID."""
    videos = []
    next_page_token = None

    while True:
        try:
            playlist_items_response = youtube.playlistItems().list(
                part='snippet',
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            ).execute()

            videos += playlist_items_response['items']
            next_page_token = playlist_items_response.get('nextPageToken')

            if next_page_token is None:
                break
        except Exception as e:
            print(f"An error occurred: {e}")
            break

    return videos
videos = get_videos_from_playlist(uploads_playlist)
print(f"Total videos: {len(videos)}")
# Out:
# Total videos: 78

# %% [markdown]
# # Save Information into a dataframe

# %%
df = pd.DataFrame([{
    'video_id': video['snippet']['resourceId']['videoId'],
    'channel_title': video['snippet']['channelTitle'],
    'title': video['snippet']['title'],
    'description': video['snippet']['description'],
    'thumbnail_url': video['snippet']['thumbnails']['maxres']['url'] if 'maxres' in video['snippet']['thumbnails'] else video['snippet']['thumbnails']['high']['url'],
} for video in videos])
df
# Out:
#        video_id                  channel_title  \
# 0   Ad44riH5CgI  استوديو القمة Alqimmah Studio
# 1   38kjm-kMjy0  استوديو القمة Alqimmah Studio
# 2   5hdN4hWWw4A  استوديو القمة Alqimmah Studio
# 3   q5NJpVFDbm4  استوديو القمة Alqimmah Studio
# 4   ZC3EMxSj8zE  استوديو القمة Alqimmah Studio
# ..          ...                            ...
# 73  Cn8P7mYLzj0  استوديو القمة Alqimmah Studio
# 74  QdU9vAJp7ww  استوديو القمة Alqimmah Studio
# 75  -xsmrhQS5Io  استوديو القمة Alqimmah Studio
# 76  gHB5admHwrE  استوديو القمة Alqimmah Studio
# 77  GjcQdCYcqzQ  استوديو القمة Alqimmah Studio
#
#                                                 title  \
# 0   منال العلا بالمرهفات القواضب | إلقاء: أسامة ال...
# 1          سورة الأنفال I القارئ: محمد السعيد المتولي
# 2        بانت سعاد- كعب بن زهير | إلقاء: أسامة الواعظ
# 3   أشبت فتىً وقبل ضحى المشيب I كلمات الشاعر: إيها...
# 4                  سورة الأحقاف I القارئ: أسامة شبانة
# ..                                                ...
# 73  لا يحمل الحقد من تعلو به الرتب- أداء: خالد الشرفي
# 74           سورة الحجرات- للقارئ عبدالرحمن عادل فهمي
# 75  لكل شيء إذا ما تم نقصان- قصيدة في رثاء الأندلس...
# 76  قصيدة حسان بن ثابت في رثاء النبي صلى الله عليه...
# 77                     سورة الصف- للقارئ حسين اليافعي
#
#                                           description  \
# 0   منال العلا بالمرهفات القواضب\nقصيدة لعلي بن ال...
# 1   تسجيل استديو القمة  لسورة الأنفال\n بصوت القار...
# 2   بانت سعاد فقلبي اليوم متبول\nقصيدة لكعب بن زهي...
# 3   أشبت فتىً وقبل ضحى المشيب\nكلمات الشاعر: إيهاب...
# 4   تسجيل استديو القمة لسورة الأحقاف\n بصوت القارئ...
# ..                                                ...
# 73  أبيات تنسب للشاعر الجاهلي عنترة بن شداد، فيها ...
# 74
# 75  كلمات القصيدة لأبي البقاء الرندي\nبصوت: أسامة ...
# 76  هذه القصيدة تنسب للصحابي الجليل حسان بن ثابت -...
# 77
#
#                                         thumbnail_url
# 0   https://i.ytimg.com/vi/Ad44riH5CgI/maxresdefau...
# 1   https://i.ytimg.com/vi/38kjm-kMjy0/maxresdefau...
# 2   https://i.ytimg.com/vi/5hdN4hWWw4A/maxresdefau...
# 3   https://i.ytimg.com/vi/q5NJpVFDbm4/maxresdefau...
# 4   https://i.ytimg.com/vi/ZC3EMxSj8zE/maxresdefau...
# ..                                                ...
# 73  https://i.ytimg.com/vi/Cn8P7mYLzj0/maxresdefau...
# 74  https://i.ytimg.com/vi/QdU9vAJp7ww/maxresdefau...
# 75  https://i.ytimg.com/vi/-xsmrhQS5Io/maxresdefau...
# 76   https://i.ytimg.com/vi/gHB5admHwrE/hqdefault.jpg
# 77  https://i.ytimg.com/vi/GjcQdCYcqzQ/maxresdefau...
#
# [78 rows x 5 columns]

# %%
# dump the data to a JSON file 
df.to_json('data.json', orient='records', force_ascii=False)

# %% [markdown]
# # Download Videos/ Audios

# %%
## find videos with title containing a specific keyword
keyword = 'أسامة الواعظ'
df_filtered = df[df['title'].str.contains(keyword, case=False)]
# replace title with keyword
df_filtered.loc[:, 'channel_title'] = keyword
df_filtered
# Out:
#        video_id channel_title  \
# 0   Ad44riH5CgI  أسامة الواعظ
# 2   5hdN4hWWw4A  أسامة الواعظ
# 12  01v6T9wghjw  أسامة الواعظ
# 17  lU12RCIusqM  أسامة الواعظ
# 24  Y0tWGG-SzCw  أسامة الواعظ
# 26  r6VpT0Lid0E  أسامة الواعظ
# 31  oWzo-SsqOVY  أسامة الواعظ
# 32  _qXLo4wTk9E  أسامة الواعظ
# 34  y6CKU_ob1xU  أسامة الواعظ
# 37  GLaWhcwEHFA  أسامة الواعظ
# 44  NAmc74KK7JI  أسامة الواعظ
# 45  brwA83WiVvo  أسامة الواعظ
# 48  lOTVs2ULX_k  أسامة الواعظ
# 49  r02Nuhxi3g0  أسامة الواعظ
# 50  YHe5baPfjOE  أسامة الواعظ
# 55  KTiiwdaL7ac  أسامة الواعظ
# 61  4P8B3jUlMRg  أسامة الواعظ
# 64  zbB2x1afhYU  أسامة الواعظ
# 69  P6QOr3SdE_Q  أسامة الواعظ
# 72  MUORJT3kPSE  أسامة الواعظ
# 75  -xsmrhQS5Io  أسامة الواعظ
# 76  gHB5admHwrE  أسامة الواعظ
#
#                                                 title  \
# 0   منال العلا بالمرهفات القواضب | إلقاء: أسامة ال...
# 2        بانت سعاد- كعب بن زهير | إلقاء: أسامة الواعظ
# 12  على قدر أهل العزم تأتي العزائم | إلقاء: أسامة ...
# 17  ألا ما لعينك أم ما لها | الخنساء | إلقاء: أسام...
# 24  أضحى التنائي بديلاً من تدانينا - إلقاء: أسام...
# 26  حكايات أحمد شوقي {١٠ قصائد} - إلقاء أسامة الواعظ
# 31              لامية ابن الوردي - إلقاء أسامة الواعظ
# 32  نظم مثلث قطرب للبهنسي مع شرحه لابن زريق - إلقا...
# 34  لعينيك ما يلقى الفؤاد وما لقي - للمتنبي I إلقا...
# 37  ألا من رأى الطفل المفارق أمه - لابن الزيات - إ...
# 44  يسلم المرءَ أخوه - قصيدة لأبي العتاهية إلقاء: ...
# 45  يا بيت عاتكة - للأحوص الأنصاري I بصوت: أسامة ا...
# 48  ياليل الصب متى غده؟ - قصيدة لعلي بن عبدالغني ا...
# 49  الأرجوزة المحبرة في التاريخ - لعلي بن الجهم - ...
# 50  الناسخ والمنسوخ في القرآن الكريم للسيوطي I أسا...
# 55                  سلي الرماح العوالي / أسامة الواعظ
# 61        بم التعلل؟ قصيدة للمتنبي بصوت: أسامة الواعظ
# 64  أراك عصي الدمع -لأبي فراس الحمداني بصوت أسامة ...
# 69     لهوى النفوس - قصيدة للمتنبي بصوت: أسامة الواعظ
# 72  الدهر ذو دول - قصيدة لأبي العتاهية - بصوت: أسا...
# 75  لكل شيء إذا ما تم نقصان- قصيدة في رثاء الأندلس...
# 76  قصيدة حسان بن ثابت في رثاء النبي صلى الله عليه...
#
#                                           description  \
# 0   منال العلا بالمرهفات القواضب\nقصيدة لعلي بن ال...
# 2   بانت سعاد فقلبي اليوم متبول\nقصيدة لكعب بن زهي...
# 12  على قدر أهل العزم تأتي العزائم\nقصيدة للمتنبي ...
# 17  ألا ما لعينك أم ما لها\nقصيدة للخنساء (ت:٢٤هـ)...
# 24  أضحى التنائي بديلاً من تدانينا\nقصيدة لابن زيد...
# 26  الحكايات من ديوان أحمد شوقي\n\nإلقاء ومونتاج: ...
# 31  لامية ابن الوردي ت749هـ\n\nإلقاء ومونتاج: أسام...
# 32  نظم مثلث قطرب \nلسديد الدين البهنسي\nمع شرحه ل...
# 34  لعينيك ما يلقى الفؤاد وما لقي\nقصيدة للمتنبي (...
# 37  ألا من رأى الطفل المفارق أمه\nقصيدة لابن الزيا...
# 44  يسلم المرء أخوه\nقصيدة لأبي العتاهية (ت: 213هـ...
# 45  يا بيت عاتكة - قصيدة للأحوص الأنصاري (ت:105هـ)...
# 48  ياليل الصب متى غده؟ \n- قصيدة لعلي بن عبدالغني...
# 49  الأرجوزة المحبرة في التاريخ لعلي بن الجهم (ت:2...
# 50  الناسخ والمنسوخ في القرآن الكريم\nقصيدة للحافظ...
# 55  سلي الرماح العوالي عن معالينا\nقصيدة لصفي الدي...
# 61  بم التعلل؟\nقصيدة للمتنبي\nبصوت: أسامة الواعظ\...
# 64  قصيدة أراك عصي الدمع لأبي فراس الحمداني المتوف...
# 69                   هذا العمل من انتاج استودية القمة
# 72
# 75  كلمات القصيدة لأبي البقاء الرندي\nبصوت: أسامة ...
# 76  هذه القصيدة تنسب للصحابي الجليل حسان بن ثابت -...
#
#                                         thumbnail_url
# 0   https://i.ytimg.com/vi/Ad44riH5CgI/maxresdefau...
# 2   https://i.ytimg.com/vi/5hdN4hWWw4A/maxresdefau...
# 12  https://i.ytimg.com/vi/01v6T9wghjw/maxresdefau...
# 17  https://i.ytimg.com/vi/lU12RCIusqM/maxresdefau...
# 24  https://i.ytimg.com/vi/Y0tWGG-SzCw/maxresdefau...
# 26  https://i.ytimg.com/vi/r6VpT0Lid0E/maxresdefau...
# 31  https://i.ytimg.com/vi/oWzo-SsqOVY/maxresdefau...
# 32  https://i.ytimg.com/vi/_qXLo4wTk9E/maxresdefau...
# 34  https://i.ytimg.com/vi/y6CKU_ob1xU/maxresdefau...
# 37   https://i.ytimg.com/vi/GLaWhcwEHFA/hqdefault.jpg
# 44   https://i.ytimg.com/vi/NAmc74KK7JI/hqdefault.jpg
# 45  https://i.ytimg.com/vi/brwA83WiVvo/maxresdefau...
# 48  https://i.ytimg.com/vi/lOTVs2ULX_k/maxresdefau...
# 49  https://i.ytimg.com/vi/r02Nuhxi3g0/maxresdefau...
# 50  https://i.ytimg.com/vi/YHe5baPfjOE/maxresdefau...
# 55  https://i.ytimg.com/vi/KTiiwdaL7ac/maxresdefau...
# 61   https://i.ytimg.com/vi/4P8B3jUlMRg/hqdefault.jpg
# 64  https://i.ytimg.com/vi/zbB2x1afhYU/maxresdefau...
# 69   https://i.ytimg.com/vi/P6QOr3SdE_Q/hqdefault.jpg
# 72  https://i.ytimg.com/vi/MUORJT3kPSE/maxresdefau...
# 75  https://i.ytimg.com/vi/-xsmrhQS5Io/maxresdefau...
# 76   https://i.ytimg.com/vi/gHB5admHwrE/hqdefault.jpg

# %%
# download the videos
ydl_opts = {
    'format': 'best',
    'outtmpl': 'videos/%(title)s.%(ext)s',
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    for video_id in df['video_id']:
        video_url = f'https://www.youtube.com/watch?v={video_id}'
        ydl.download([video_url])

# %%
import yt_dlp
import os
import pandas as pd

# Path to ffmpeg and ffprobe
ffmpeg_path = os.getenv('FFMPEG_PATH')
ffprope_path = os.getenv('FFPROBE_PATH')

# Verify that ffmpeg and ffprobe exist at the specified locations
if not os.path.exists(ffmpeg_path):
    raise FileNotFoundError(f"ffmpeg not found at {ffmpeg_path}")
if not os.path.exists(ffprope_path):
    raise FileNotFoundError(f"ffprobe not found at {ffprope_path}")

# Adjust yt_dlp options
ydl_opts = {
    'format': 'bestaudio',
    'outtmpl': 'music/%(title)s.%(ext)s',
    'ffmpeg_path': ffmpeg_path,  # Specify ffmpeg location
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }, {
        'key': 'EmbedThumbnail',
    }, {
        'key': 'FFmpegMetadata',
        'add_metadata': True,
    }],
    'postprocessor_args': [
        '-metadata', 'artist=CHANNEL_NAME_PLACEHOLDER'
    ]
}

# Function to download videos
def download_videos_as_audio(df):
    for idx, row in df.iterrows():
        video_id = row['video_id']
        # Update artist metadata
        ydl_opts['postprocessor_args'] = ['-metadata', f'artist={row["channel_title"]}', 
                                          '-metadata', f'title={row["title"]}',
                                            ]
                                          
        
        # Use context manager to apply options
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            video_url = f'https://www.youtube.com/watch?v={video_id}'
            ydl.download([video_url])

# Call the function to download videos
download_videos_as_audio(df_filtered)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ad44riH5CgI
# [youtube] Ad44riH5CgI: Downloading webpage
# [youtube] Ad44riH5CgI: Downloading ios player API JSON
# [youtube] Ad44riH5CgI: Downloading m3u8 information
# [info] Ad44riH5CgI: Downloading 1 format(s): 251
# [download] Destination: music\منال العلا بالمرهفات القواضب ｜ إلقاء： أسامة الواعظ.webm
# [download] 100% of    7.88MiB in 00:00:02 at 3.42MiB/s
# [ExtractAudio] Destination: music\منال العلا بالمرهفات القواضب ｜ إلقاء： أسامة الواعظ.mp3
# Deleting original file music\منال العلا بالمرهفات القواضب ｜ إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\منال العلا بالمرهفات القواضب ｜ إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5hdN4hWWw4A
# [youtube] 5hdN4hWWw4A: Downloading webpage
# [youtube] 5hdN4hWWw4A: Downloading ios player API JSON
# [youtube] 5hdN4hWWw4A: Downloading m3u8 information
# [info] 5hdN4hWWw4A: Downloading 1 format(s): 251
# [download] Destination: music\بانت سعاد- كعب بن زهير ｜ إلقاء： أسامة الواعظ.webm
# [download] 100% of   11.83MiB in 00:00:03 at 3.61MiB/s
# [ExtractAudio] Destination: music\بانت سعاد- كعب بن زهير ｜ إلقاء： أسامة الواعظ.mp3
# Deleting original file music\بانت سعاد- كعب بن زهير ｜ إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\بانت سعاد- كعب بن زهير ｜ إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=01v6T9wghjw
# [youtube] 01v6T9wghjw: Downloading webpage
# [youtube] 01v6T9wghjw: Downloading ios player API JSON
# [youtube] 01v6T9wghjw: Downloading m3u8 information
# [info] 01v6T9wghjw: Downloading 1 format(s): 251
# [download] Destination: music\على قدر أهل العزم تأتي العزائم ｜ إلقاء： أسامة الواعظ.webm
# [download] 100% of    8.09MiB in 00:00:02 at 3.60MiB/s
# [ExtractAudio] Destination: music\على قدر أهل العزم تأتي العزائم ｜ إلقاء： أسامة الواعظ.mp3
# Deleting original file music\على قدر أهل العزم تأتي العزائم ｜ إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\على قدر أهل العزم تأتي العزائم ｜ إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lU12RCIusqM
# [youtube] lU12RCIusqM: Downloading webpage
# [youtube] lU12RCIusqM: Downloading ios player API JSON
# [youtube] lU12RCIusqM: Downloading m3u8 information
# [info] lU12RCIusqM: Downloading 1 format(s): 251
# [download] Destination: music\ألا ما لعينك أم ما لها ｜ الخنساء ｜ إلقاء： أسامة الواعظ.webm
# [download] 100% of    5.42MiB in 00:00:01 at 3.39MiB/s
# [ExtractAudio] Destination: music\ألا ما لعينك أم ما لها ｜ الخنساء ｜ إلقاء： أسامة الواعظ.mp3
# Deleting original file music\ألا ما لعينك أم ما لها ｜ الخنساء ｜ إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\ألا ما لعينك أم ما لها ｜ الخنساء ｜ إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Y0tWGG-SzCw
# [youtube] Y0tWGG-SzCw: Downloading webpage
# [youtube] Y0tWGG-SzCw: Downloading ios player API JSON
# [youtube] Y0tWGG-SzCw: Downloading m3u8 information
# [info] Y0tWGG-SzCw: Downloading 1 format(s): 251
# [download] Destination: music\أضحى التنائي بديلاً من تدانينا - إلقاء： أسامة الواعظ.webm
# [download] 100% of   11.02MiB in 00:00:03 at 3.44MiB/s
# [ExtractAudio] Destination: music\أضحى التنائي بديلاً من تدانينا - إلقاء： أسامة الواعظ.mp3
# Deleting original file music\أضحى التنائي بديلاً من تدانينا - إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\أضحى التنائي بديلاً من تدانينا - إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=r6VpT0Lid0E
# [youtube] r6VpT0Lid0E: Downloading webpage
# [youtube] r6VpT0Lid0E: Downloading ios player API JSON
# [youtube] r6VpT0Lid0E: Downloading m3u8 information
# [info] r6VpT0Lid0E: Downloading 1 format(s): 251
# [download] Destination: music\حكايات أحمد شوقي {١٠ قصائد} - إلقاء أسامة الواعظ.webm
# [download] 100% of   19.42MiB in 00:00:05 at 3.53MiB/s
# [ExtractAudio] Destination: music\حكايات أحمد شوقي {١٠ قصائد} - إلقاء أسامة الواعظ.mp3
# Deleting original file music\حكايات أحمد شوقي {١٠ قصائد} - إلقاء أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\حكايات أحمد شوقي {١٠ قصائد} - إلقاء أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oWzo-SsqOVY
# [youtube] oWzo-SsqOVY: Downloading webpage
# [youtube] oWzo-SsqOVY: Downloading ios player API JSON
# [youtube] oWzo-SsqOVY: Downloading m3u8 information
# [info] oWzo-SsqOVY: Downloading 1 format(s): 251
# [download] Destination: music\لامية ابن الوردي - إلقاء أسامة الواعظ.webm
# [download] 100% of   10.47MiB in 00:00:03 at 2.64MiB/s
# [ExtractAudio] Destination: music\لامية ابن الوردي - إلقاء أسامة الواعظ.mp3
# Deleting original file music\لامية ابن الوردي - إلقاء أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\لامية ابن الوردي - إلقاء أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_qXLo4wTk9E
# [youtube] _qXLo4wTk9E: Downloading webpage
# [youtube] _qXLo4wTk9E: Downloading ios player API JSON
# [youtube] _qXLo4wTk9E: Downloading m3u8 information
# [info] _qXLo4wTk9E: Downloading 1 format(s): 251
# [download] Destination: music\نظم مثلث قطرب للبهنسي مع شرحه لابن زريق - إلقاء： أسامة الواعظ.webm
# [download] 100% of   14.82MiB in 00:00:04 at 3.52MiB/s
# [ExtractAudio] Destination: music\نظم مثلث قطرب للبهنسي مع شرحه لابن زريق - إلقاء： أسامة الواعظ.mp3
# Deleting original file music\نظم مثلث قطرب للبهنسي مع شرحه لابن زريق - إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\نظم مثلث قطرب للبهنسي مع شرحه لابن زريق - إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=y6CKU_ob1xU
# [youtube] y6CKU_ob1xU: Downloading webpage
# [youtube] y6CKU_ob1xU: Downloading ios player API JSON
# [youtube] y6CKU_ob1xU: Downloading m3u8 information
# [info] y6CKU_ob1xU: Downloading 1 format(s): 251
# [download] Destination: music\لعينيك ما يلقى الفؤاد وما لقي - للمتنبي I إلقاء： أسامة الواعظ.webm
# [download] 100% of    8.62MiB in 00:00:02 at 3.55MiB/s
# [ExtractAudio] Destination: music\لعينيك ما يلقى الفؤاد وما لقي - للمتنبي I إلقاء： أسامة الواعظ.mp3
# Deleting original file music\لعينيك ما يلقى الفؤاد وما لقي - للمتنبي I إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\لعينيك ما يلقى الفؤاد وما لقي - للمتنبي I إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GLaWhcwEHFA
# [youtube] GLaWhcwEHFA: Downloading webpage
# [youtube] GLaWhcwEHFA: Downloading ios player API JSON
# [youtube] GLaWhcwEHFA: Downloading m3u8 information
# [info] GLaWhcwEHFA: Downloading 1 format(s): 251
# [download] Destination: music\ألا من رأى الطفل المفارق أمه - لابن الزيات - إلقاء： أسامة الواعظ.webm
# [download] 100% of    5.46MiB in 00:00:01 at 3.63MiB/s
# [ExtractAudio] Destination: music\ألا من رأى الطفل المفارق أمه - لابن الزيات - إلقاء： أسامة الواعظ.mp3
# Deleting original file music\ألا من رأى الطفل المفارق أمه - لابن الزيات - إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\ألا من رأى الطفل المفارق أمه - لابن الزيات - إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NAmc74KK7JI
# [youtube] NAmc74KK7JI: Downloading webpage
# [youtube] NAmc74KK7JI: Downloading ios player API JSON
# [youtube] NAmc74KK7JI: Downloading m3u8 information
# [info] NAmc74KK7JI: Downloading 1 format(s): 251
# [download] Destination: music\يسلم المرءَ أخوه - قصيدة لأبي العتاهية إلقاء： أسامة الواعظ.webm
# [download] 100% of    3.08MiB in 00:00:00 at 3.70MiB/s
# [ExtractAudio] Destination: music\يسلم المرءَ أخوه - قصيدة لأبي العتاهية إلقاء： أسامة الواعظ.mp3
# Deleting original file music\يسلم المرءَ أخوه - قصيدة لأبي العتاهية إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\يسلم المرءَ أخوه - قصيدة لأبي العتاهية إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=brwA83WiVvo
# [youtube] brwA83WiVvo: Downloading webpage
# [youtube] brwA83WiVvo: Downloading ios player API JSON
# [youtube] brwA83WiVvo: Downloading m3u8 information
# [info] brwA83WiVvo: Downloading 1 format(s): 251
# [download] Destination: music\يا بيت عاتكة - للأحوص الأنصاري I بصوت： أسامة الواعظ.webm
# [download] 100% of    9.02MiB in 00:00:02 at 3.60MiB/s
# [ExtractAudio] Destination: music\يا بيت عاتكة - للأحوص الأنصاري I بصوت： أسامة الواعظ.mp3
# Deleting original file music\يا بيت عاتكة - للأحوص الأنصاري I بصوت： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\يا بيت عاتكة - للأحوص الأنصاري I بصوت： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lOTVs2ULX_k
# [youtube] lOTVs2ULX_k: Downloading webpage
# [youtube] lOTVs2ULX_k: Downloading ios player API JSON
# [youtube] lOTVs2ULX_k: Downloading m3u8 information
# [info] lOTVs2ULX_k: Downloading 1 format(s): 251
# [download] Destination: music\ياليل الصب متى غده؟ - قصيدة لعلي بن عبدالغني الحصري القيرواني بصوت： أسامة الواعظ.webm
# [download] 100% of    4.34MiB in 00:00:01 at 3.63MiB/s
# [ExtractAudio] Destination: music\ياليل الصب متى غده؟ - قصيدة لعلي بن عبدالغني الحصري القيرواني بصوت： أسامة الواعظ.mp3
# Deleting original file music\ياليل الصب متى غده؟ - قصيدة لعلي بن عبدالغني الحصري القيرواني بصوت： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\ياليل الصب متى غده؟ - قصيدة لعلي بن عبدالغني الحصري القيرواني بصوت： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=r02Nuhxi3g0
# [youtube] r02Nuhxi3g0: Downloading webpage
# [youtube] r02Nuhxi3g0: Downloading ios player API JSON
# [youtube] r02Nuhxi3g0: Downloading m3u8 information
# [info] r02Nuhxi3g0: Downloading 1 format(s): 251
# [download] Destination: music\الأرجوزة المحبرة في التاريخ - لعلي بن الجهم - إلقاء： أسامة الواعظ.webm
# [download] 100% of   41.99MiB in 00:00:16 at 2.62MiB/s
# [ExtractAudio] Destination: music\الأرجوزة المحبرة في التاريخ - لعلي بن الجهم - إلقاء： أسامة الواعظ.mp3
# Deleting original file music\الأرجوزة المحبرة في التاريخ - لعلي بن الجهم - إلقاء： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\الأرجوزة المحبرة في التاريخ - لعلي بن الجهم - إلقاء： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YHe5baPfjOE
# [youtube] YHe5baPfjOE: Downloading webpage
# [youtube] YHe5baPfjOE: Downloading ios player API JSON
# [youtube] YHe5baPfjOE: Downloading m3u8 information
# [info] YHe5baPfjOE: Downloading 1 format(s): 251
# [download] Destination: music\الناسخ والمنسوخ في القرآن الكريم للسيوطي I أسامة الواعظ.webm
# [download] 100% of    2.13MiB in 00:00:00 at 3.35MiB/s
# [ExtractAudio] Destination: music\الناسخ والمنسوخ في القرآن الكريم للسيوطي I أسامة الواعظ.mp3
# Deleting original file music\الناسخ والمنسوخ في القرآن الكريم للسيوطي I أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\الناسخ والمنسوخ في القرآن الكريم للسيوطي I أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KTiiwdaL7ac
# [youtube] KTiiwdaL7ac: Downloading webpage
# [youtube] KTiiwdaL7ac: Downloading ios player API JSON
# [youtube] KTiiwdaL7ac: Downloading m3u8 information
# [info] KTiiwdaL7ac: Downloading 1 format(s): 251
# [download] Destination: music\سلي الرماح العوالي ⧸ أسامة الواعظ.webm
# [download] 100% of    6.26MiB in 00:00:02 at 2.22MiB/s
# [ExtractAudio] Destination: music\سلي الرماح العوالي ⧸ أسامة الواعظ.mp3
# Deleting original file music\سلي الرماح العوالي ⧸ أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\سلي الرماح العوالي ⧸ أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4P8B3jUlMRg
# [youtube] 4P8B3jUlMRg: Downloading webpage
# [youtube] 4P8B3jUlMRg: Downloading ios player API JSON
# [youtube] 4P8B3jUlMRg: Downloading m3u8 information
# [info] 4P8B3jUlMRg: Downloading 1 format(s): 251
# [download] Destination: music\بم التعلل؟ قصيدة للمتنبي بصوت： أسامة الواعظ.webm
# [download] 100% of    5.25MiB in 00:00:01 at 3.55MiB/s
# [ExtractAudio] Destination: music\بم التعلل؟ قصيدة للمتنبي بصوت： أسامة الواعظ.mp3
# Deleting original file music\بم التعلل؟ قصيدة للمتنبي بصوت： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\بم التعلل؟ قصيدة للمتنبي بصوت： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zbB2x1afhYU
# [youtube] zbB2x1afhYU: Downloading webpage
# [youtube] zbB2x1afhYU: Downloading ios player API JSON
# [youtube] zbB2x1afhYU: Downloading m3u8 information
# [info] zbB2x1afhYU: Downloading 1 format(s): 251
# [download] Destination: music\أراك عصي الدمع -لأبي فراس الحمداني بصوت أسامة الواعظ.webm
# [download] 100% of    8.92MiB in 00:00:06 at 1.32MiB/s
# [ExtractAudio] Destination: music\أراك عصي الدمع -لأبي فراس الحمداني بصوت أسامة الواعظ.mp3
# Deleting original file music\أراك عصي الدمع -لأبي فراس الحمداني بصوت أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\أراك عصي الدمع -لأبي فراس الحمداني بصوت أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=P6QOr3SdE_Q
# [youtube] P6QOr3SdE_Q: Downloading webpage
# [youtube] P6QOr3SdE_Q: Downloading ios player API JSON
# [youtube] P6QOr3SdE_Q: Downloading m3u8 information
# [info] P6QOr3SdE_Q: Downloading 1 format(s): 251
# [download] Destination: music\لهوى النفوس - قصيدة للمتنبي بصوت： أسامة الواعظ.webm
# [download] 100% of    5.24MiB in 00:00:01 at 3.48MiB/s
# [ExtractAudio] Destination: music\لهوى النفوس - قصيدة للمتنبي بصوت： أسامة الواعظ.mp3
# Deleting original file music\لهوى النفوس - قصيدة للمتنبي بصوت： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\لهوى النفوس - قصيدة للمتنبي بصوت： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MUORJT3kPSE
# [youtube] MUORJT3kPSE: Downloading webpage
# [youtube] MUORJT3kPSE: Downloading ios player API JSON
# [youtube] MUORJT3kPSE: Downloading m3u8 information
# [info] MUORJT3kPSE: Downloading 1 format(s): 251
# [download] Destination: music\الدهر ذو دول - قصيدة لأبي العتاهية - بصوت： أسامة الواعظ.webm
# [download] 100% of    5.16MiB in 00:00:01 at 3.17MiB/s
# [ExtractAudio] Destination: music\الدهر ذو دول - قصيدة لأبي العتاهية - بصوت： أسامة الواعظ.mp3
# Deleting original file music\الدهر ذو دول - قصيدة لأبي العتاهية - بصوت： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\الدهر ذو دول - قصيدة لأبي العتاهية - بصوت： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-xsmrhQS5Io
# [youtube] -xsmrhQS5Io: Downloading webpage
# [youtube] -xsmrhQS5Io: Downloading ios player API JSON
# [youtube] -xsmrhQS5Io: Downloading m3u8 information
# [info] -xsmrhQS5Io: Downloading 1 format(s): 251
# [download] Destination: music\لكل شيء إذا ما تم نقصان- قصيدة في رثاء الأندلس- بصوت： أسامة الواعظ.webm
# [download] 100% of    8.76MiB in 00:00:02 at 3.31MiB/s
# [ExtractAudio] Destination: music\لكل شيء إذا ما تم نقصان- قصيدة في رثاء الأندلس- بصوت： أسامة الواعظ.mp3
# Deleting original file music\لكل شيء إذا ما تم نقصان- قصيدة في رثاء الأندلس- بصوت： أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\لكل شيء إذا ما تم نقصان- قصيدة في رثاء الأندلس- بصوت： أسامة الواعظ.mp3"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gHB5admHwrE
# [youtube] gHB5admHwrE: Downloading webpage
# [youtube] gHB5admHwrE: Downloading ios player API JSON
# [youtube] gHB5admHwrE: Downloading m3u8 information
# [info] gHB5admHwrE: Downloading 1 format(s): 251
# [download] Destination: music\قصيدة حسان بن ثابت في رثاء النبي صلى الله عليه وسلم- بصوت أسامة الواعظ.webm
# [download] 100% of   10.76MiB in 00:00:03 at 3.12MiB/s
# [ExtractAudio] Destination: music\قصيدة حسان بن ثابت في رثاء النبي صلى الله عليه وسلم- بصوت أسامة الواعظ.mp3
# Deleting original file music\قصيدة حسان بن ثابت في رثاء النبي صلى الله عليه وسلم- بصوت أسامة الواعظ.webm (pass -k to keep)
# [EmbedThumbnail] There are no thumbnails on disk
# [Metadata] Adding metadata to "music\قصيدة حسان بن ثابت في رثاء النبي صلى الله عليه وسلم- بصوت أسامة الواعظ.mp3"
